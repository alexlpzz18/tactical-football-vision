# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics supervision lapx scikit-learn

# %%
# %cd /content/tactical-football-vision
# !git pull
# Out:
# /content/tactical-football-vision
# Already up to date.

# %%
import sys
sys.path.append('/content/tactical-football-vision')
from src.pipeline import run_pipeline
print("Import OK")
# Out:
# Import OK

# %%
import os

video_path = '/content/drive/MyDrive/tactical-football-vision-data/videos/raw/A.D. Villaviciosa de Odón ＂C＂ 1 - 1 C.D. Rupe Sahagún ＂A＂.mp4'
model_path = '/content/drive/MyDrive/tactical-football-vision-data/best_v2.pt'
output_path = '/content/drive/MyDrive/tactical-football-vision-data/outputs/villaviciosa_tracked.mp4'

os.makedirs('/content/drive/MyDrive/tactical-football-vision-data/outputs', exist_ok=True)

run_pipeline(
    video_path=video_path,
    model_path=model_path,
    output_path=output_path,
    confidence=0.3
)
# Out:
# ...
# Vídeo: /content/drive/MyDrive/tactical-football-vision-data/videos/raw/A.D. Villaviciosa de Odón ＂C＂ 1 - 1 C.D. Rupe Sahagún ＂A＂.mp4
# Resolución: 640x360 @ 30.0fps
# Total frames: 18098
# Procesando vídeo...
# Clasificador entrenado en frame 0
# Progreso: 0.6% (100/18098)
# Progreso: 1.1% (200/18098)
# Progreso: 1.7% (300/18098)
# Progreso: 2.2% (400/18098)
# Progreso: 2.8% (500/18098)
# Progreso: 3.3% (600/18098)
# Progreso: 3.9% (700/18098)
# Progreso: 4.4% (800/18098)
# Progreso: 5.0% (900/18098)
# Progreso: 5.5% (1000/18098)
# Progreso: 6.1% (1100/18098)
# Progreso: 6.6% (1200/18098)
# Progreso: 7.2% (1300/18098)
# Progreso: 7.7% (1400/18098)
# Progreso: 8.3% (1500/18098)
# Progreso: 8.8% (1600/18098)
# Progreso: 9.4% (1700/18098)
# Progreso: 9.9% (1800/18098)
# Progreso: 10.5% (1900/18098)
# Progreso: 11.1% (2000/18098)
# Progreso: 11.6% (2100/18098)
# Progreso: 12.2% (2200/18098)
# Progreso: 12.7% (2300/18098)
# Progreso: 13.3% (2400/18098)
# Progreso: 13.8% (2500/18098)
# ...
