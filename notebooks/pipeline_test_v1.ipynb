# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics supervision lapx scikit-learn

# %%
# %cd /content/tactical-football-vision
# !git pull
# Out:
# /content/tactical-football-vision
# Already up to date.

# %%
import sys
sys.path.append('/content/tactical-football-vision')
from src.pipeline import run_pipeline
print("Import OK")
# Out:
# Import OK

# %%
import os

video_path = '/content/drive/MyDrive/tactical-football-vision-data/videos/raw/SUNDAY LEAGUE FULL MATCH ｜ Sarisbury Spartans v Aldershot Park Elite.mp4'
model_path = '/content/drive/MyDrive/tactical-football-vision-data/best_v2.pt'
output_path = '/content/drive/MyDrive/tactical-football-vision-data/outputs/sunday_league_tracked.mp4'

run_pipeline(
    video_path=video_path,
    model_path=model_path,
    output_path=output_path,
    confidence=0.3
)
# Out:
# Vídeo: /content/drive/MyDrive/tactical-football-vision-data/videos/raw/SUNDAY LEAGUE FULL MATCH ｜ Sarisbury Spartans v Aldershot Park Elite.mp4
# Resolución: 640x360 @ 30.0fps
# Total frames: 18019
# Procesando vídeo...
# Clasificador entrenado en frame 0
# Progreso: 0.6% (100/18019)
# Progreso: 1.1% (200/18019)
# Progreso: 1.7% (300/18019)
# Progreso: 2.2% (400/18019)
# Progreso: 2.8% (500/18019)
